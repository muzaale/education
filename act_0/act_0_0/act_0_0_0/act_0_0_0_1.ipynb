# %% [markdown]
# #
#
# <iframe width="744" height="419" src="https://www.youtube.com/embed/4S2iggRVQEE" title="Johns Hopkins Briefing: Could ChatGPT Upend Education?" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#
# <Details>
#    <Summary></Summary>
#
# [ChatGPT & K12 education](https://hub.jhu.edu/2023/09/26/briefing-artificial-intelligence-education/?utm_source=Hub+-+Synced+List&utm_campaign=efbad23cf2-EMAIL_CAMPAIGN_2023_09_27_09_16&utm_medium=email&utm_term=0_3aa22d10c7-efbad23cf2-%5BLIST_EMAIL_ID%5D&mc_cid=efbad23cf2&mc_eid=2ef47a44dd)
#
# 1. Students become less interested in learning about the world around them
# 2. Perpetuates existing biases
# 3. Is outright wrong/hallucinating
# 4. Concerns about cheating by educators are misssing the point:
#    - The point is you should change the curriculum
#    - What was content is now in the LLM
#    - Question is: GIVEN that we've outsourced content, then what?
#    - No room for discussion about whether or not we've outsourced content
# 5. What really are the "ends" of education?
#
# ---
#
# - Transparency
# - `Hallucination` (cure is engineering goals like coding, webapp creation, problem soling, not "facts" or "truth" checks)
# - Dangers/Risks
# - Maximize creative thinking
# - And minimize rote learning
# - Creativity need to incorporate it
# - GPT is a superpower without doubt: can be used for good or bad
#    - We see this tool in making good students even better
#    - Less students will be made even worse (cheat)
# - Homeworks should use AI to solve real-world problems, not exam problems
# - Room of people with no coding experience to do tasks
# - Like having your own personal research assistant
#
# 1. Ontology: Truth (trust) vs. False (credible) type usage comes from "justice/morality/spirit"
# 2. Epistemology: Knowledge type question like
# 3. Identity: Continuing to perpetuate racist, sexist biases - learns from human data
# 4. Security: Entry point through children's data into chat
# 5. Legal: Proprietary material used opens legal cases or may not be avalable: peer-review, etc
#
# + Disrupting education (undesired by most panelists)
# </Details>
#
# ---
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <br>
# <br>
# <Details>
#    <Summary>🏧</Summary>
#
# </Details>
#
# <Details>
#    <Summary>🌕</Summary>
# </Details>
#
# <Details>
#    <Summary>🪙</Summary>
#
# </Details>
#
# <Details>
#    <Summary>🌟</Summary>
#
# </Details>
#
# <Details>
#    <Summary>💵</Summary>
#
# </Details>
#
# <Details>
#    <Summary>💸</Summary>
# </Details>
#
# <Details>
#    <Summary>💰</Summary>
#
# </Details>
#
# <Details>
#    <Summary>🎁</Summary>
#
# </Details>
#
# <Details>
#    <Summary>💴</Summary>
#
# </Details>
#
# <Details>
#    <Summary>💯</Summary>
#
# </Details>
#
# <Details>
#    <Summary>🏆</Summary>
#
# </Details>
#
# <Details>
#    <Summary>💲</Summary>
#
# </Details>
#
# <Details>
#    <Summary>💀</Summary>
#
# </Details>
